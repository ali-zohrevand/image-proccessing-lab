# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-zohrevand/image-proccessing-lab/blob/main/image_proccessing_HW_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Question 1:**

# %%
# How to Import an image
from google.colab import files
import matplotlib.pyplot as plt

# Select file from Local Drive

# %% [markdown]
# a) Computes the difference between values in neighboring pixels and Find the number of bytes
# and size of the image, and display each case

# %%
img = plt.imread('drive/MyDrive/Image_Proccessing/Home_Works/image1.jpg')
print(img)
# Out:
# [[[ 91 108 118]
#   [ 91 108 118]
#   [ 91 108 118]
#   ...
#   [ 39  57   7]
#   [ 38  55  11]
#   [ 37  54  12]]
#
#  [[ 91 108 118]
#   [ 91 108 118]
#   [ 91 108 118]
#   ...
#   [ 39  57   9]
#   [ 38  55  11]
#   [ 37  54  12]]
#
#  [[ 92 109 119]
#   [ 92 109 119]
#   [ 92 109 119]
#   ...
#   [ 38  56   8]
#   [ 37  54  10]
#   [ 36  53  11]]
#
#  ...
#
#  [[ 35  30  24]
#   [ 35  30  24]
#   [ 35  30  24]
#   ...
#   [109  74 104]
#   [110  75 105]
#   [110  76 103]]
#
#  [[ 34  29  23]
#   [ 34  29  23]
#   [ 34  29  23]
#   ...
#   [106  73 102]
#   [106  73 100]
#   [108  74 101]]
#
#  [[ 33  28  22]
#   [ 33  28  22]
#   [ 33  28  22]
#   ...
#   [105  72 101]
#   [105  72  99]
#   [106  73 100]]]

# %%
# finding the difference between
# neighboring elements
result = np.diff(img)
  
print(result)
# Out:
# [[[ 17  10]
#   [ 17  10]
#   [ 17  10]
#   ...
#   [ 18 206]
#   [ 17 212]
#   [ 17 214]]
#
#  [[ 17  10]
#   [ 17  10]
#   [ 17  10]
#   ...
#   [ 18 208]
#   [ 17 212]
#   [ 17 214]]
#
#  [[ 17  10]
#   [ 17  10]
#   [ 17  10]
#   ...
#   [ 18 208]
#   [ 17 212]
#   [ 17 214]]
#
#  ...
#
#  [[251 250]
#   [251 250]
#   [251 250]
#   ...
#   [221  30]
#   [221  30]
#   [222  27]]
#
#  [[251 250]
#   [251 250]
#   [251 250]
#   ...
#   [223  29]
#   [223  27]
#   [222  27]]
#
#  [[251 250]
#   [251 250]
#   [251 250]
#   ...
#   [223  29]
#   [223  27]
#   [223  27]]]

# %% [markdown]
# b: Representation the image with unit-8 data type, default type (float 64) and by adding bias (128)
# and plot it.

# %%
# Convert uploaded image into uint type
img = plt.imread('drive/MyDrive/Image_Proccessing/Home_Works/image1.jpg')

# Confirm pixel dtype, shape and range(should be 0-255)
print('Data Type:',img.dtype)
print('Data Shape:',img.shape, "bytes")
print('Data size:',img.size)
print('Min: %.3f, Max: %.3f' % (img.min(), img.max()))
plt.imshow(img)
# Out:
# Data Type: uint8
# Data Shape: (168, 300, 3) bytes
# Data size: 151200
# Min: 0.000, Max: 255.000

# %%
def convert(img, target_type_min, target_type_max, target_type):
    imin = img.min()
    imax = img.max()

    a = (target_type_max - target_type_min) / (imax - imin)
    b = target_type_max - a * imax
    new_img = (a * img + b).astype(target_type)
    return new_img

# %%
import numpy as np

# %%
new_image=convert(img,0,128,np.uint8)

# %% [markdown]
# # **128 bits**

# %%
plt.imshow(new_image)

# %% [markdown]
# # **64 bits**

# %%
new_image_64=convert(img,0,64,np.uint8)

# %%
plt.imshow(new_image_64)

# %% [markdown]
# c) How many bits can manage so that we still have a good image? Plot all of the cases.

# %% [markdown]
# # **32 bits**

# %%
new_image_32=convert(img,0,32,np.uint8)
plt.imshow(new_image_32)

# %% [markdown]
# # **16 bits**

# %%
new_image_16=convert(img,0,16,np.uint8)
plt.imshow(new_image_16)

# %% [markdown]
# # **8 bits**

# %%
new_image_8=convert(img,0,8,np.uint8)
plt.imshow(new_image_8)

# %% [markdown]
# # **4 bits**

# %%
new_image_4=convert(img,0,4,np.uint8)
plt.imshow(new_image_4)

# %% [markdown]
# # **Question 2:**

# %%
import cv2
import matplotlib.pyplot as plt

# %%
src = cv2.imread('image2.jpg', cv2.IMREAD_UNCHANGED)
plt.imshow(src)

# %%
#percent by which the image is resized
scale_percent = 150
# Out:
# (225, 225, 3)

# %%
#calculate the 50 percent of original dimensions
width = int(src.shape[1] * scale_percent / 100)
height = int(src.shape[0] * scale_percent / 100)

# %%
# dsize
dsize = (width, height)

# %%
output = cv2.resize(src, dsize)
plt.imshow(output)

# %%
from PIL import Image

 

# Create an Image object from an Image

colorImage  = Image.open("drive/MyDrive/Image_Proccessing/Home_Works/image2.jpg")

 

# Rotate it by 90 degrees

transposed  = colorImage.transpose(Image.ROTATE_90)

# %% [markdown]
# **Rotate it by 90 degrees**

# %%
# Display the Original Image

plt.imshow(transposed)

# %% [markdown]
# # **Question 3**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('drive/MyDrive/Image_Proccessing/Home_Works/image3.jpg',0)
plt.imshow(img)

# %%
plt.hist(img.ravel(),256,[0,256]); 
plt.show()

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-side
cv2.imwrite('res.png',res)
plt.imshow(res)

# %% [markdown]
# **equalization**

# %%
plt.hist(equ.ravel(),256,[0,256]); 
plt.show()

# %% [markdown]
# # **PMF**

# %%
x=img
u, cnt = np.unique(x, return_counts=True)
plt.stem(u, cnt/len(x), use_line_collection=True)
plt.ylim(0,None)
plt.show()

# %% [markdown]
# **After equlization:**

# %%
x=equ
u, cnt = np.unique(x, return_counts=True)
plt.stem(u, cnt/len(x), use_line_collection=True)
plt.ylim(0,None)
plt.show()

# %% [markdown]
# **CDF**

# %%
# getting data of the histogram
count, bins_count = np.histogram(img, bins=10)
  
# finding the PDF of the histogram using count values
pdf = count / sum(count)
  
# using numpy np.cumsum to calculate the CDF
# We can also find using the PDF values by looping and adding
cdf = np.cumsum(pdf)
  
# plotting PDF and CDF
plt.plot(bins_count[1:], pdf, color="red", label="PDF")
plt.plot(bins_count[1:], cdf, label="CDF")
plt.legend()

# %% [markdown]
# **After equalization**

# %%
# getting data of the histogram
count, bins_count = np.histogram(equ, bins=10)
  
# finding the PDF of the histogram using count values
pdf = count / sum(count)
  
# using numpy np.cumsum to calculate the CDF
# We can also find using the PDF values by looping and adding
cdf = np.cumsum(pdf)
  
# plotting PDF and CDF
plt.plot(bins_count[1:], pdf, color="red", label="PDF")
plt.plot(bins_count[1:], cdf, label="CDF")
plt.legend()
